# %%
import numpy as np

# %%
def main():
    A = 2*np.pi
    B = A/1000
    for x in np.arange(0,A,B):
        print("The sin of ",x," is ",np.sin(x))

# %%
if __name__ == "__main__":
    main()
# Out:
# The sin of  0.0  is  0.0
# The sin of  0.006283185307179587  is  0.006283143965558951
# The sin of  0.012566370614359173  is  0.012566039883352607
# The sin of  0.01884955592153876  is  0.018848439715408175
# The sin of  0.025132741228718346  is  0.02513009544333748
# The sin of  0.031415926535897934  is  0.03141075907812829
# The sin of  0.03769911184307752  is  0.03769018266993454
# The sin of  0.04398229715025711  is  0.04396811831786491
# The sin of  0.05026548245743669  is  0.050244318179769556
# The sin of  0.05654866776461628  is  0.05651853448202453
# The sin of  0.06283185307179587  is  0.06279051952931337
# The sin of  0.06911503837897545  is  0.0690600257144058
# The sin of  0.07539822368615504  is  0.07532680552793272
# The sin of  0.08168140899333462  is  0.08159061156815754
# The sin of  0.08796459430051422  is  0.08785119655074318
# The sin of  0.0942477796076938  is  0.09410831331851433
# The sin of  0.10053096491487339  is  0.1003617148512149
# ...
